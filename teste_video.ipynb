# %%
from ultralytics import YOLO
import cv2

# Carregar o modelo
model = YOLO('C:\\Users\\píchau\\Documents\\TCC\\yolov8-env\\runs\\detect\\train_11_no_prep_no_HP\\weights\\best.pt')  # Substitua pelo caminho do seu modelo

# Abrir o vídeo
cap = cv2.VideoCapture('C:\\Users\\píchau\\Documents\\TCC\\videos\\video5.mp4')

# Definir saída do vídeo
output_path = "C:\\Users\\píchau\\Documents\\TCC\\videos\\output_video5.mp4"
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
fps = int(cap.get(cv2.CAP_PROP_FPS))
frame_width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
frame_height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
out = cv2.VideoWriter(output_path, fourcc, fps, (frame_width, frame_height))

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    results = model.predict(frame)  # Detectar objetos no frame
    result = results[0]
    boxes = result.boxes

    # Verifique se existem caixas detectadas
    if len(boxes) > 0:
        for box in boxes:  # Para cada caixa de detecção (primeiro item da lista)
            x1, y1, x2, y2 = box.xyxy[0]  # Coordenadas no formato (x1, y1, x2, y2)
            confidence = box.conf[0]  # Confiança da detecção
            class_id = box.cls[0]  # ID da classe da detecção

            # Desenha a caixa no frame
            cv2.rectangle(frame, (int(x1), int(y1)), (int(x2), int(y2)), (0, 255, 0), 2)
            
            # Coloca o texto sobre a caixa com a classe e a confiança
            label = f"{result.names[int(class_id)]} {confidence:.2f}"
            cv2.putText(frame, label, (int(x1), int(y1) - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.5, (0, 255, 0), 2)


    # Mostrar o resultado
    out.write(frame)
    #cv2.imshow('frame', frame)
    #if cv2.waitKey(1) & 0xFF == ord('q'):
    #    break

# Fechar o vídeo
cap.release()
out.release()
#cv2.destroyAllWindows()
# Out:
# 0: 384x640 54 apples, 51.8ms
# Speed: 3.3ms preprocess, 51.8ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 52 apples, 11.5ms
# Speed: 2.2ms preprocess, 11.5ms inference, 0.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 47 apples, 7.4ms
# Speed: 15.8ms preprocess, 7.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 41 apples, 16.8ms
# Speed: 0.0ms preprocess, 16.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 40 apples, 0.0ms
# Speed: 0.0ms preprocess, 0.0ms inference, 13.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 apples, 13.1ms
# Speed: 3.2ms preprocess, 13.1ms inference, 0.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 apples, 16.8ms
# Speed: 0.0ms preprocess, 16.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 38 apples, 7.3ms
# ...
